# %%
import glob
import pandas as pd

# %% [markdown]
# Combining all the csv files

# %%
path = r"D:\guvi\data\cardheko"
file_list = glob.glob(path + r"/*.csv")
csv_list = []
for file in file_list:
    csv_list.append(pd.read_csv(file))

# %%
df = pd.concat(csv_list, ignore_index=True)
df
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 4     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 8364  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 8365  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 8366  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 8367  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 8368  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# 4     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...                                                 ...
# 8364  {'heading': 'Car overview', 'top': [{'key': 'R...
# 8365  {'heading': 'Car overview', 'top': [{'key': 'R...
# 8366  {'heading': 'Car overview', 'top': [{'key': 'R...
# 8367  {'heading': 'Car overview', 'top': [{'key': 'R...
# 8368  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                         new_car_feature  \
# 0     {'heading': 'Features', 'top': [{'value': 'Pow...
# 1     {'heading': 'Features', 'top': [{'value': 'Pow...
# 2     {'heading': 'Features', 'top': [{'value': 'Pow...
# 3     {'heading': 'Features', 'top': [{'value': 'Pow...
# 4     {'heading': 'Features', 'top': [{'value': 'Pow...
# ...                                                 ...
# 8364  {'heading': 'Features', 'top': [{'value': 'Pow...
# 8365  {'heading': 'Features', 'top': [{'value': 'Pow...
# 8366  {'heading': 'Features', 'top': [{'value': 'Pow...
# 8367  {'heading': 'Features', 'top': [{'value': 'Pow...
# 8368  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                           new_car_specs  \
# 0     {'heading': 'Specifications', 'top': [{'key': ...
# 1     {'heading': 'Specifications', 'top': [{'key': ...
# 2     {'heading': 'Specifications', 'top': [{'key': ...
# 3     {'heading': 'Specifications', 'top': [{'key': ...
# 4     {'heading': 'Specifications', 'top': [{'key': ...
# ...                                                 ...
# 8364  {'heading': 'Specifications', 'top': [{'key': ...
# 8365  {'heading': 'Specifications', 'top': [{'key': ...
# 8366  {'heading': 'Specifications', 'top': [{'key': ...
# 8367  {'heading': 'Specifications', 'top': [{'key': ...
# 8368  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                               car_links
# 0     https://www.cardekho.com/used-car-details/used...
# 1     https://www.cardekho.com/buy-used-car-details/...
# 2     https://www.cardekho.com/used-car-details/used...
# 3     https://www.cardekho.com/buy-used-car-details/...
# 4     https://www.cardekho.com/used-car-details/used...
# ...                                                 ...
# 8364  https://www.cardekho.com/used-car-details/used...
# 8365  https://www.cardekho.com/used-car-details/used...
# 8366  https://www.cardekho.com/used-car-details/used...
# 8367  https://www.cardekho.com/used-car-details/used...
# 8368  https://www.cardekho.com/used-car-details/used...
#
# [8369 rows x 5 columns]

# %%
car_details = df['new_car_detail']
car_overview = df['new_car_overview']
car_feature = df['new_car_feature']
car_specs = df['new_car_specs']

# %% [markdown]
# Car Details

# %%
import ast
details_list = []
for i in car_details:
    res = ast.literal_eval(i)
    details_list.append(res)

# %%
details_list[0]
# Out:
# {'it': 0,
#  'ft': 'Petrol',
#  'bt': 'Hatchback',
#  'km': '1,20,000',
#  'transmission': 'Manual',
#  'ownerNo': 3,
#  'owner': '3rd Owner',
#  'oem': 'Maruti',
#  'model': 'Maruti Celerio',
#  'modelYear': 2015,
#  'centralVariantId': 3979,
#  'variantName': 'VXI',
#  'price': '₹ 4 Lakh',
#  'priceActual': '',
#  'priceSaving': '',
#  'priceFixedText': None,
#  'trendingText': {'imgUrl': 'https://stimg.cardekho.com/used-cars/common/icons/trending.svg',
#   'heading': 'Trending Car!',
#   'desc': 'High chances of sale in next 6 days'}}

# %%
columns = {'ignition_type': [], 'Fuel_Type': [],'body_type': [],'kms_driven': [],'transmission_type': [],'owner_No': [],'owner': [],
           'manufacturer':[],'model': [],'Manufacture_year':[],'variantName':[],'centralVariantId':[],'price':[],'priceActual': [],
           'priceSaving': [],'priceFixedText': []}
for dic in details_list:
    columns['ignition_type'].append(dic['it'])
    columns['Fuel_Type'].append(dic['ft'])
    columns['body_type'].append(dic['bt'])
    columns['kms_driven'].append(dic['km'])
    columns['transmission_type'].append(dic['transmission'])
    columns['owner_No'].append(dic['ownerNo'])
    columns['owner'].append(dic['owner'])
    columns['manufacturer'].append(dic['oem'])
    columns['model'].append(dic['model'])
    columns['Manufacture_year'].append(dic['modelYear'])
    columns['variantName'].append(dic['variantName'])
    columns['centralVariantId'].append(dic['centralVariantId'])
    columns['price'].append(dic['price'])
    columns['priceActual'].append(dic['priceActual'])
    columns['priceSaving'].append(dic['priceSaving'])
    columns['priceFixedText'].append(dic['priceFixedText'])

details_df = pd.DataFrame(columns)
details_df
# Out:
#       ignition_type Fuel_Type  body_type kms_driven transmission_type  \
# 0                 0    Petrol  Hatchback   1,20,000            Manual
# 1                 0    Petrol        SUV     32,706            Manual
# 2                 0    Petrol  Hatchback     11,949            Manual
# 3                 0    Petrol      Sedan     17,794            Manual
# 4                 0    Diesel        SUV     60,000            Manual
# ...             ...       ...        ...        ...               ...
# 8364              0    Petrol  Hatchback     10,000            Manual
# 8365              0    Petrol  Hatchback   1,20,000            Manual
# 8366              0    Petrol      Sedan     50,000         Automatic
# 8367              0    Petrol  Hatchback     40,000            Manual
# 8368              0    Diesel        SUV   1,20,000            Manual
#
#       owner_No      owner   manufacturer                  model  \
# 0            3  3rd Owner         Maruti         Maruti Celerio
# 1            2  2nd Owner           Ford          Ford Ecosport
# 2            1  1st Owner           Tata             Tata Tiago
# 3            1  1st Owner        Hyundai          Hyundai Xcent
# 4            1  1st Owner         Maruti     Maruti SX4 S Cross
# ...        ...        ...            ...                    ...
# 8364         1  1st Owner         Maruti         Maruti Celerio
# 8365         1  1st Owner         Maruti        Maruti Alto 800
# 8366         3  3rd Owner  Mercedes-Benz  Mercedes-Benz C-Class
# 8367         1  1st Owner         Maruti            Maruti Ritz
# 8368         2  2nd Owner        Renault         Renault Duster
#
#       Manufacture_year               variantName  centralVariantId  \
# 0                 2015                       VXI              3979
# 1                 2018  1.5 Petrol Titanium BSIV              6087
# 2                 2018           1.2 Revotron XZ              2983
# 3                 2014        1.2 Kappa S Option              1867
# 4                 2015             DDiS 200 Zeta              4277
# ...                ...                       ...               ...
# 8364              2022                  ZXI BSVI              8682
# 8365              2014                       LXI              3943
# 8366              2011        C 200 CGI Elegance              4672
# 8367              2012                       ZXi              4144
# 8368              2017      110PS Diesel RxZ AWD              5048
#
#             price priceActual priceSaving priceFixedText
# 0        ₹ 4 Lakh                                   None
# 1     ₹ 8.11 Lakh                                   None
# 2     ₹ 5.85 Lakh                                   None
# 3     ₹ 4.62 Lakh                                   None
# 4     ₹ 7.90 Lakh                                   None
# ...           ...         ...         ...            ...
# 8364  ₹ 5.10 Lakh                                   None
# 8365  ₹ 1.80 Lakh                                   None
# 8366  ₹ 5.50 Lakh                                   None
# 8367  ₹ 1.40 Lakh                                   None
# 8368     ₹ 5 Lakh                                   None
#
# [8369 rows x 16 columns]

# %% [markdown]
# Car overview

# %%
import ast
import pandas as pd

def car_overview(d, parent_key='', sep='_'):
    items = []
    for key, value in d.items():
        new_key = f'{parent_key}{sep}{key}' if parent_key else key
        if isinstance(value, dict):
            items.extend(car_overview(value, new_key, sep).items()) 
        else:
            items.append((new_key, value))  
    return dict(items)

overview_data = []
for index, row in df.iterrows():
    try:
        unstructured_data = ast.literal_eval(row['new_car_overview'])
        overview_row = car_overview(unstructured_data)  
        overview_data.append(overview_row)
    
    except Exception as e:
        print(f"Error at index {index}: {e}") 

overview_df = pd.DataFrame(overview_data)
overview_df.head()
# Out:
#         heading                                                top bottomData
# 0  Car overview  [{'key': 'Registration Year', 'value': '2015',...       None
# 1  Car overview  [{'key': 'Registration Year', 'value': 'Feb 20...       None
# 2  Car overview  [{'key': 'Registration Year', 'value': 'Sept 2...       None
# 3  Car overview  [{'key': 'Registration Year', 'value': 'Dec 20...       None
# 4  Car overview  [{'key': 'Registration Year', 'value': '2015',...       None

# %%
def overview_dict(row):
    if isinstance(row, list):
        return {d['key']: d['value'] for d in row}
    return{}
df['new_car_overview'] = overview_df['top'].apply(overview_dict)
overview_df = pd.DataFrame(df['new_car_overview'].tolist())
overview_df
# Out:
#      Registration Year     Insurance Validity Fuel Type    Seats  \
# 0                 2015  Third Party insurance    Petrol  5 Seats
# 1             Feb 2018          Comprehensive    Petrol  5 Seats
# 2            Sept 2018          Comprehensive    Petrol  5 Seats
# 3             Dec 2014          Comprehensive    Petrol  5 Seats
# 4                 2015  Third Party insurance    Diesel  5 Seats
# ...                ...                    ...       ...      ...
# 8364              2022  Third Party insurance    Petrol  5 Seats
# 8365              2014  Third Party insurance    Petrol  5 Seats
# 8366              2011  Third Party insurance    Petrol  5 Seats
# 8367              2012  Third Party insurance    Petrol  5 Seats
# 8368              2017  Third Party insurance    Diesel  5 Seats
#
#         Kms Driven   RTO     Ownership Engine Displacement Transmission  \
# 0     1,20,000 Kms  KA51   Third Owner              998 cc       Manual
# 1       32,706 Kms  KA05  Second Owner             1497 cc       Manual
# 2       11,949 Kms  KA03   First Owner             1199 cc       Manual
# 3       17,794 Kms  KA53   First Owner             1197 cc       Manual
# 4       60,000 Kms  KA04   First Owner             1248 cc       Manual
# ...            ...   ...           ...                 ...          ...
# 8364    10,000 Kms   NaN   First Owner              998 cc       Manual
# 8365  1,20,000 Kms   NaN   First Owner              796 cc       Manual
# 8366    50,000 Kms  WB06   Third Owner             1796 cc    Automatic
# 8367    40,000 Kms   NaN   First Owner             1197 cc       Manual
# 8368  1,20,000 Kms   NaN  Second Owner             1461 cc       Manual
#
#       Year of Manufacture
# 0                  2015.0
# 1                  2018.0
# 2                  2018.0
# 3                  2014.0
# 4                  2015.0
# ...                   ...
# 8364               2022.0
# 8365               2014.0
# 8366               2011.0
# 8367               2012.0
# 8368               2017.0
#
# [8369 rows x 10 columns]

# %% [markdown]
# Car feature

# %%
import ast
import pandas as pd
def feature_dict(row):
    feature_data = ast.literal_eval(row)
    features = [item['value'] for item in feature_data.get('top', [])]
    return features

df['features'] = df['new_car_feature'].apply(feature_dict)
features_df = df.explode('features')[['features']]
features_df.reset_index(drop=True, inplace=True)
features_df.head()
# Out:
#                  features
# 0          Power Steering
# 1     Power Windows Front
# 2         Air Conditioner
# 3                  Heater
# 4  Adjustable Head Lights

# %% [markdown]
# Car Specifications

# %%
import ast
import pandas as pd

def car_spec(d, parent_key='', sep='_'):
    items = []
    for key, value in d.items():
        new_key = f'{parent_key}{sep}{key}' if parent_key else key
        if isinstance(value, dict):
            items.extend(car_spec(value, new_key, sep).items()) 
        else:
            items.append((new_key, value))  
    return dict(items)

spec_data = []
for index, row in df.iterrows():
    try:
        unstructured_data = ast.literal_eval(row['new_car_specs'])
        spec_row = car_spec(unstructured_data)  
        spec_data.append(spec_row)
    
    except Exception as e:
        print(f"Error at index {index}: {e}") 

spec_df = pd.DataFrame(spec_data)
spec_df
# Out:
#              heading                                                top  \
# 0     Specifications  [{'key': 'Mileage', 'value': '23.1 kmpl'}, {'k...
# 1     Specifications  [{'key': 'Mileage', 'value': '17 kmpl'}, {'key...
# 2     Specifications  [{'key': 'Mileage', 'value': '23.84 kmpl'}, {'...
# 3     Specifications  [{'key': 'Mileage', 'value': '19.1 kmpl'}, {'k...
# 4     Specifications  [{'key': 'Mileage', 'value': '23.65 kmpl'}, {'...
# ...              ...                                                ...
# 8364  Specifications  [{'key': 'Mileage', 'value': '25.24 kmpl'}, {'...
# 8365  Specifications  [{'key': 'Mileage', 'value': '22.74 kmpl'}, {'...
# 8366  Specifications  [{'key': 'Mileage', 'value': '11.74 kmpl'}, {'...
# 8367  Specifications  [{'key': 'Mileage', 'value': '18.5 kmpl'}, {'k...
# 8368  Specifications  [{'key': 'Mileage', 'value': '19.72 kmpl'}, {'...
#
#                                                    data commonIcon
# 0     [{'heading': 'Engine and Transmission', 'subHe...
# 1     [{'heading': 'Engine and Transmission', 'subHe...
# 2     [{'heading': 'Engine and Transmission', 'subHe...
# 3     [{'heading': 'Engine and Transmission', 'subHe...
# 4     [{'heading': 'Engine and Transmission', 'subHe...
# ...                                                 ...        ...
# 8364  [{'heading': 'Engine and Transmission', 'subHe...
# 8365  [{'heading': 'Engine and Transmission', 'subHe...
# 8366  [{'heading': 'Engine and Transmission', 'subHe...
# 8367  [{'heading': 'Engine and Transmission', 'subHe...
# 8368  [{'heading': 'Engine and Transmission', 'subHe...
#
# [8369 rows x 4 columns]

# %%
def spec_dict(row):
    if isinstance(row,list):
        return {d['key']:d['value'] for d in row}
    return{}
df['new_car_specs'] = spec_df['top'].apply(spec_dict)
spec_df = pd.DataFrame(df['new_car_specs'].tolist())
spec_df
# Out:
#          Mileage   Engine  Max Power    Torque Seats Wheel Size
# 0      23.1 kmpl   998 CC   67.04bhp      90Nm     5        NaN
# 1        17 kmpl  1497 CC  121.31bhp     150Nm     5         16
# 2     23.84 kmpl  1199 CC      84bhp     114Nm     5         14
# 3      19.1 kmpl  1197 CC   81.86bhp  113.75Nm     5         14
# 4     23.65 kmpl  1248 CC    88.5bhp     200Nm     5         16
# ...          ...      ...        ...       ...   ...        ...
# 8364  25.24 kmpl   998 CC   65.71bhp      89Nm     5        NaN
# 8365  22.74 kmpl   796 CC    47.3bhp      69Nm     5        NaN
# 8366  11.74 kmpl  1796 CC     186bhp     285Nm     5         17
# 8367   18.5 kmpl  1197 CC   85.80bhp     114Nm     5         14
# 8368  19.72 kmpl  1461 CC  108.45bhp     245Nm     5         16
#
# [8369 rows x 6 columns]

# %% [markdown]
# Dropping unwanted columns

# %%
details_df.drop(columns=['ignition_type','priceFixedText','priceSaving','owner','priceActual',
                         'centralVariantId','variantName'],inplace=True)

# %%
overview_df.drop(columns=['Fuel Type','Seats','Kms Driven','RTO','Ownership','Engine Displacement','Transmission',
                          'Year of Manufacture'],inplace=True)

# %%
spec_df.drop(columns=['Wheel Size'],inplace=True)

# %%
car_df = pd.concat([details_df,overview_df,spec_df],axis=1)

# %%
car_df
# Out:
#      Fuel_Type  body_type kms_driven transmission_type  owner_No  \
# 0       Petrol  Hatchback   1,20,000            Manual         3
# 1       Petrol        SUV     32,706            Manual         2
# 2       Petrol  Hatchback     11,949            Manual         1
# 3       Petrol      Sedan     17,794            Manual         1
# 4       Diesel        SUV     60,000            Manual         1
# ...        ...        ...        ...               ...       ...
# 8364    Petrol  Hatchback     10,000            Manual         1
# 8365    Petrol  Hatchback   1,20,000            Manual         1
# 8366    Petrol      Sedan     50,000         Automatic         3
# 8367    Petrol  Hatchback     40,000            Manual         1
# 8368    Diesel        SUV   1,20,000            Manual         2
#
#        manufacturer                  model  Manufacture_year        price  \
# 0            Maruti         Maruti Celerio              2015     ₹ 4 Lakh
# 1              Ford          Ford Ecosport              2018  ₹ 8.11 Lakh
# 2              Tata             Tata Tiago              2018  ₹ 5.85 Lakh
# 3           Hyundai          Hyundai Xcent              2014  ₹ 4.62 Lakh
# 4            Maruti     Maruti SX4 S Cross              2015  ₹ 7.90 Lakh
# ...             ...                    ...               ...          ...
# 8364         Maruti         Maruti Celerio              2022  ₹ 5.10 Lakh
# 8365         Maruti        Maruti Alto 800              2014  ₹ 1.80 Lakh
# 8366  Mercedes-Benz  Mercedes-Benz C-Class              2011  ₹ 5.50 Lakh
# 8367         Maruti            Maruti Ritz              2012  ₹ 1.40 Lakh
# 8368        Renault         Renault Duster              2017     ₹ 5 Lakh
#
#      Registration Year     Insurance Validity     Mileage   Engine  Max Power  \
# 0                 2015  Third Party insurance   23.1 kmpl   998 CC   67.04bhp
# 1             Feb 2018          Comprehensive     17 kmpl  1497 CC  121.31bhp
# 2            Sept 2018          Comprehensive  23.84 kmpl  1199 CC      84bhp
# 3             Dec 2014          Comprehensive   19.1 kmpl  1197 CC   81.86bhp
# 4                 2015  Third Party insurance  23.65 kmpl  1248 CC    88.5bhp
# ...                ...                    ...         ...      ...        ...
# 8364              2022  Third Party insurance  25.24 kmpl   998 CC   65.71bhp
# 8365              2014  Third Party insurance  22.74 kmpl   796 CC    47.3bhp
# 8366              2011  Third Party insurance  11.74 kmpl  1796 CC     186bhp
# 8367              2012  Third Party insurance   18.5 kmpl  1197 CC   85.80bhp
# 8368              2017  Third Party insurance  19.72 kmpl  1461 CC  108.45bhp
#
#         Torque Seats
# 0         90Nm     5
# 1        150Nm     5
# 2        114Nm     5
# 3     113.75Nm     5
# 4        200Nm     5
# ...        ...   ...
# 8364      89Nm     5
# 8365      69Nm     5
# 8366     285Nm     5
# 8367     114Nm     5
# 8368     245Nm     5
#
# [8369 rows x 16 columns]

# %% [markdown]
# Converting columns to numerical

# %%
import pandas as pd
import re
def extract_numbers(text):
    numbers = re.findall(r'\d+\.?\d*', str(text))  
    return numbers[0] if numbers else None 
       
car_df['Mileage'] = car_df['Mileage'].apply(extract_numbers)
car_df['Engine'] =car_df['Engine'].apply(extract_numbers)
car_df['Max Power'] = car_df['Max Power'].apply(extract_numbers)
car_df['Torque'] = car_df['Torque'].apply(extract_numbers)

# %%
def price_convert(price):
    if pd.isna(price):
        return None    
    price = str(price).strip()      
    if 'Lakh' in price:
        return float(re.sub(r'[^\d.]', '', price)) * 100000
    elif 'Cr' in price:
        return float(re.sub(r'[^\d.]', '', price)) * 10000000
    else:
        cleaned_price = re.sub(r'[^\d.]', '', price)
        return float(cleaned_price) if cleaned_price else None
car_df['price'] = car_df['price'].apply(price_convert)

# %% [markdown]
# Handling the missing values

# %%
car_df.loc[car_df['model'] == 'Maruti Gypsy', 'Seats'] = '8 Seats'
car_df.loc[car_df['model'] == 'MG Gloster', 'Seats'] = '6 Seats'
car_df.loc[car_df['model'] == 'Maruti 800', 'Seats'] = '4 Seats'
car_df.loc[car_df['model'] == 'Mahindra e2o Plus', 'Seats'] = '4 Seats'
car_df.loc[car_df['model'] == 'Maruti Omni', 'Seats'] = '8 Seats'
car_df.loc[car_df['model'] == 'Toyota Qualis', 'Seats'] = '8 Seats'
car_df.loc[car_df['model'] == 'Ford Endeavour', 'Seats'] = '7 Seats'
car_df.loc[car_df['model'] == 'Mahindra XUV700', 'Seats'] = '7 Seats'
car_df.loc[car_df['model'] == 'Maruti Gypsy', 'Engine'] = '1298 '
car_df.loc[car_df['model'] == 'Mahindra e2o Plus', 'Engine'] = '72 '
car_df.loc[car_df['model'] == 'Mercedes-Benz C-Class', 'Engine'] = '1496'

# %% [markdown]
# Droping null values

# %%
car_df.dropna(inplace=True)

# %%
car_df.isnull().sum()
# Out:
# Fuel_Type             0
# body_type             0
# kms_driven            0
# transmission_type     0
# owner_No              0
# manufacturer          0
# model                 0
# Manufacture_year      0
# price                 0
# Registration Year     0
# Insurance Validity    0
# Mileage               0
# Engine                0
# Max Power             0
# Torque                0
# Seats                 0
# dtype: int64

# %% [markdown]
# Romeving string values

# %%
car_df['Registration Year'] = car_df['Registration Year'].str.extract(r'(\d+)').astype(int)
car_df['Seats'] = car_df['Seats'].str.extract(r'(\d+)').astype(int)
car_df['kms_driven']=car_df['kms_driven'].str.replace(',','')

# %% [markdown]
# Encoding the columns

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

car_df['Fuel_Type'] = le.fit_transform(car_df['Fuel_Type'])
car_df['body_type'] = le.fit_transform(car_df['body_type'])
car_df['transmission_type'] = le.fit_transform(car_df['transmission_type'])
car_df['manufacturer'] = le.fit_transform(car_df['manufacturer'])
car_df['model'] = le.fit_transform(car_df['model'])
car_df['Insurance Validity'] = le.fit_transform(car_df['Insurance Validity'])

# %%
car_df
# Out:
#       Fuel_Type  body_type kms_driven  transmission_type  owner_No  \
# 0             4          3     120000                  1         3
# 1             4          8      32706                  1         2
# 2             4          3      11949                  1         1
# 3             4          9      17794                  1         1
# 4             1          8      60000                  1         1
# ...         ...        ...        ...                ...       ...
# 8364          4          3      10000                  1         1
# 8365          4          3     120000                  1         1
# 8366          4          9      50000                  0         3
# 8367          4          3      40000                  1         1
# 8368          1          8     120000                  1         2
#
#       manufacturer  model  Manufacture_year     price  Registration Year  \
# 0               20    142              2015  400000.0               2015
# 1                6     47              2018  811000.0               2018
# 2               29    242              2018  585000.0               2018
# 3                9     81              2014  462000.0               2014
# 4               20    157              2015  790000.0               2015
# ...            ...    ...               ...       ...                ...
# 8364            20    142              2022  510000.0               2022
# 8365            20    137              2014  180000.0               2014
# 8366            21    171              2011  550000.0               2011
# 8367            20    154              2012  140000.0               2012
# 8368            27    208              2017  500000.0               2017
#
#       Insurance Validity Mileage Engine Max Power  Torque  Seats
# 0                      5    23.1    998     67.04      90      5
# 1                      2      17   1497    121.31     150      5
# 2                      2   23.84   1199        84     114      5
# 3                      2    19.1   1197     81.86  113.75      5
# 4                      5   23.65   1248      88.5     200      5
# ...                  ...     ...    ...       ...     ...    ...
# 8364                   5   25.24    998     65.71      89      5
# 8365                   5   22.74    796      47.3      69      5
# 8366                   5   11.74   1496       186     285      5
# 8367                   5    18.5   1197     85.80     114      5
# 8368                   5   19.72   1461    108.45     245      5
#
# [7998 rows x 16 columns]

# %%
car_df.to_csv('final_cars_data.csv',index=False)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import numpy as np

# %% [markdown]
# Linear Regression Model

# %%
x = car_df.drop(['price'],axis=1)
y = car_df['price']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)


LR=LinearRegression()
LR.fit(x_train,y_train)

train_pred=LR.predict(x_train)
test_pred=LR.predict(x_test)

# %%
print('*********Train data*******')
print('R2 score:',metrics.r2_score(y_train, train_pred ))
print("MAE :",metrics.mean_absolute_error(y_train,train_pred ))
print("MSE :",metrics.mean_squared_error(y_train,train_pred ))
print('RMSE :', np.sqrt(metrics.mean_squared_error(y_train,train_pred )))

print('**********Test data********')
print('R2 score:',metrics.r2_score(y_test,test_pred))
print("MAE :",metrics.mean_absolute_error(y_test,test_pred))
print("MSE :",metrics.mean_squared_error(y_test,test_pred))
print('RMSE :', np.sqrt(metrics.mean_squared_error(y_test,test_pred)))
# Out:
# *********Train data*******
# R2 score: 0.6478337842119395
# MAE : 343018.9603483459
# MSE : 478636648005.8551
# RMSE : 691835.708825336
# **********Test data********
# R2 score: 0.7093089821620764
# MAE : 336102.5048982996
# MSE : 365310593728.0525
# RMSE : 604409.2932178099

# %% [markdown]
# Random Forest Model

# %%
RM = RandomForestRegressor()
RM.fit(x_train,y_train)

train_pred=RM.predict(x_train)
test_pred=RM.predict(x_test)

print('*********Train data*******')
print('R2 score:',metrics.r2_score(y_train, train_pred ))
print("MAE :",metrics.mean_absolute_error(y_train,train_pred ))
print("MSE :",metrics.mean_squared_error(y_train,train_pred ))
print('RMSE :', np.sqrt(metrics.mean_squared_error(y_train,train_pred )))

print('**********Test data********')
print('R2 score:',metrics.r2_score(y_test,test_pred))
print("MAE :",metrics.mean_absolute_error(y_test,test_pred))
print("MSE :",metrics.mean_squared_error(y_test,test_pred))
print('RMSE :', np.sqrt(metrics.mean_squared_error(y_test,test_pred)))
# Out:
# *********Train data*******
# R2 score: 0.978714691610615
# MAE : 52899.302812932605
# MSE : 28929318607.31762
# RMSE : 170086.20933902203
# **********Test data********
# R2 score: 0.8296935780788322
# MAE : 135043.7502828373
# MSE : 214023606819.56207
# RMSE : 462626.85484044487

# %% [markdown]
# Decision Tree Model

# %%
DT_model =  DecisionTreeRegressor()
DT_model.fit(x_train,y_train)

train_pred = DT_model.predict(x_train)
test_pred = DT_model.predict(x_test)

print('*********Train data*******')
print('R2 score:',metrics.r2_score(y_train, train_pred ))
print("MAE :",metrics.mean_absolute_error(y_train,train_pred ))
print("MSE :",metrics.mean_squared_error(y_train,train_pred ))
print('RMSE :', np.sqrt(metrics.mean_squared_error(y_train,train_pred )))

print('**********Test data********')
print('R2 score:',metrics.r2_score(y_test,test_pred))
print("MAE :",metrics.mean_absolute_error(y_test,test_pred))
print("MSE :",metrics.mean_squared_error(y_test,test_pred))
print('RMSE :', np.sqrt(metrics.mean_squared_error(y_test,test_pred)))
# Out:
# *********Train data*******
# R2 score: 0.9998631074689812
# MAE : 1757.9191413983538
# MSE : 186053571.42857143
# RMSE : 13640.145579449343
# **********Test data********
# R2 score: 0.7952412544228435
# MAE : 171741.25354166664
# MSE : 257319746148.83954
# RMSE : 507266.9377643683
